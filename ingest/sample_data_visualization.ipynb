# %% [markdown]
# Below is code used to visualize the the real_acct.txt file found within the real_acct_owner.zip file.

# %%
# Loaded variable 'df' from URI: /home/ed/PropertyTaxAI/ingest/real_acct.tsv
import pandas as pd
df_iter = pd.read_csv(r'/home/ed/PropertyTaxAI/ingest/real_acct.tsv', sep='\x09', 
                    engine='python', 
                    encoding='MacRoman', 
                    escapechar='\\', 
                    on_bad_lines='warn', chunksize=4500)

# %%
df_sample=next(df_iter)
